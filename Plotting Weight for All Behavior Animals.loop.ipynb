# %%
#importing libraries needed 
import pandas as pd
import xlrd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  

import seaborn as sns #style 

from matplotlib import colors

# %%
xl0 = pd.read_excel('TrainingLog.161114.xls')
# pulling out the desired rows- get the vectors we will plt from the columns  
desRow1 = xl0['Subject']==1069  #input name of animal 
desRow2= xl0['Subject']==1077
desRow3=xl0['Subject']==1086
desRow4=xl0['Subject']==1070
#desRow5=xl0['Subject']==1078 - giving an error for 6/13- can't convert string to float 
desRow6=xl0['Subject']==1079
desRow7=xl0['Subject']==1000
desRow8=xl0['Subject']==1071
desRow9=xl0['Subject']==1068
desRow10=xl0['Subject']== 1066
desRow11=xl0['Subject']==1114
desRow12=xl0['Subject']==1085
desRow13=xl0['Subject']==1087
desRow14=xl0['Subject']==1088
desRow15=xl0['Subject']== 1064

animalID=['1069','1077','1086','1070','1079','1000','1071','1068','1066','1114','1085','1087','1088','1064']

#x=date- need to index for all animals 
x=[[xl0.loc[desRow1, 'Date']], [xl0.loc[desRow2, 'Date']],[xl0.loc[desRow3,'Date']], [xl0.loc[desRow4,'Date']],
   [xl0.loc[desRow6,'Date']],[xl0.loc[desRow7,'Date']],[xl0.loc[desRow8,'Date']],
   [xl0.loc[desRow9,'Date']],[xl0.loc[desRow10,'Date']],[xl0.loc[desRow11,'Date']],[xl0.loc[desRow12,'Date']],
   [xl0.loc[desRow13,'Date']],[xl0.loc[desRow14,'Date']],[xl0.loc[desRow15,'Date']]]
# y =weight
y=[[xl0.loc[desRow1, 'Weight']],[xl0.loc[desRow2, 'Weight']],[xl0.loc[desRow3,'Weight']],[xl0.loc[desRow4,'Weight']],
  [xl0.loc[desRow6,'Weight']],[xl0.loc[desRow7,'Weight']],[xl0.loc[desRow8,'Weight']],
  [xl0.loc[desRow9,'Weight']],[xl0.loc[desRow10,'Weight']],[xl0.loc[desRow11,'Weight']],[xl0.loc[desRow12,'Weight']],
   [xl0.loc[desRow13,'Weight']],[xl0.loc[desRow14,'Weight']],[xl0.loc[desRow15,'Weight']]]



index=0

for i in range (len(x)):
    #print(animalID[0])
    #animalID+=1
    #[animalID.index(z),for z in animalID]
    plt.figure()
    plt.plot(x[i],y[i],'.-', color='green',marker='o',markerfacecolor='blue', markersize=2.5)
    plt.xticks(rotation=50) 
    plt.subplots_adjust(bottom=0.05) 
    plt.ylabel('Weight (g)', color='b', fontsize=18)
    plt.ylim([19,30])
    plt.title('Behavior Animal ', color='b', fontsize=20, fontweight='bold')
    #for name in range (len(animalID)):   # trying to print animal number with each loop  
        #print(animalID)
        #index += 1
            #could try to create a for loop within title? -
